# %%
from bs4 import BeautifulSoup
import requests

import pandas as pd
import numpy as np

from random import randint
from time import sleep

from scrape_cl import *

# %%
start_url = 'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates'

# %%
def get_results_urls(start_url):
    '''
    Function to get a list of all possible URLs based on total search results
    
    Input:  start_url = first page of listings to be scraped
    Output: results_urls = list of results urls with listings to scrape.
    '''
    
    response = requests.get(start_url)
    page = response.text
    soup = BeautifulSoup(page, 'html.parser')

    total_listings = int(soup.find('span', class_='totalcount').text)
    total_listings

    pages = np.arange(0, total_listings+1, 120)
    pages = pages[:len(pages)-1]

    results_urls = []

    for page in pages:
    
        url_prefix = start_url
        suffix = '&s='

        url = url_prefix + suffix + str(page)
    
        results_urls.append(url)
        
    return results_urls

# %%
get_results_urls(start_url)
# Out:
# ['https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=0',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=120',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=240',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=360',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=480',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=600',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=720',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=840',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=960',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1080',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1200',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1320',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1440',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1560',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1680',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1800',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=1920',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=2040',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=2160',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=2280',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=2400',
#  'https://sacramento.craigslist.org/search/apa?bundleDuplicates=1&availabilityMode=0&sale_date=all+dates&s=2520']

# %%
def full_listings_scrape(start_url):
    '''
    Function to fully scrape Craigslist results of apartments/housing search. 
    
    Process: (1) Loops through results URLs
             (2) Scrapes listings page into dataframe
             (3) Scrapes individual postings from listings page and add to df
             (4) Adds df to a list of dataframes
             (5) Moves to next URL in results_urls, repeat setps 2-4 until all pages scraped
             (6) Compiles list of dfs into single dataframe
    
    Input:   start_urls
    Output:  dataframe of entire search results
    '''
    
    df_list = []
    page_counter = 1
    
    results_urls = get_results_urls(start_url)
    
    total_pages = len(results_urls)

    for url in results_urls:
    
        response = requests.get(url)
        
        # Set sleep timer to avoid request overloads
        sleep(randint(2,4))
        
        # Status updates while scraping: 
        print("Scraping page {} of {}...".format(page_counter, total_pages))
        print("")
        df = full_page_scrape(url)
        df_list.append(df)
    
        print("")
        print("Page {} of {} scrape complete!".format(page_counter, total_pages))
        print("")
    
        page_counter += 1
    
    compiled_df = pd.concat(df_list).reset_index()
    compiled_df.to_csv('Sacramento_CL_scrape.csv', index=False)
    
    return compiled_df

# %%
full_listings_scrape(start_url)
# Out:
# Scraping page 1 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 121
#
# Individual posts scrape complete!
# Number of posts scraped:  121
#
# Page 1 of 22 scrape complete!
#
# Scraping page 2 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 121
#
# Individual posts scrape complete!
# Number of posts scraped:  121
#
# Page 2 of 22 scrape complete!
#
# Scraping page 3 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 125
#
# Individual posts scrape complete!
# Number of posts scraped:  125
#
# Page 3 of 22 scrape complete!
#
# Scraping page 4 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 122
#
# Individual posts scrape complete!
# Number of posts scraped:  122
#
# Page 4 of 22 scrape complete!
#
# Scraping page 5 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 121
#
# Individual posts scrape complete!
# Number of posts scraped:  121
#
# Page 5 of 22 scrape complete!
#
# Scraping page 6 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 121
#
# Individual posts scrape complete!
# Number of posts scraped:  121
#
# Page 6 of 22 scrape complete!
#
# Scraping page 7 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 123
#
# Individual posts scrape complete!
# Number of posts scraped:  123
#
# Page 7 of 22 scrape complete!
#
# Scraping page 8 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 121
#
# Individual posts scrape complete!
# Number of posts scraped:  121
#
# Page 8 of 22 scrape complete!
#
# Scraping page 9 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 128
#
# Individual posts scrape complete!
# Number of posts scraped:  128
#
# Page 9 of 22 scrape complete!
#
# Scraping page 10 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 131
#
# Individual posts scrape complete!
# Number of posts scraped:  131
#
# Page 10 of 22 scrape complete!
#
# Scraping page 11 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 125
#
# Individual posts scrape complete!
# Number of posts scraped:  125
#
# Page 11 of 22 scrape complete!
#
# Scraping page 12 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 125
#
# Individual posts scrape complete!
# Number of posts scraped:  125
#
# Page 12 of 22 scrape complete!
#
# Scraping page 13 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 127
#
# Individual posts scrape complete!
# Number of posts scraped:  127
#
# Page 13 of 22 scrape complete!
#
# Scraping page 14 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 129
#
# Individual posts scrape complete!
# Number of posts scraped:  129
#
# Page 14 of 22 scrape complete!
#
# Scraping page 15 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 123
#
# Individual posts scrape complete!
# Number of posts scraped:  123
#
# Page 15 of 22 scrape complete!
#
# Scraping page 16 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 129
#
# Individual posts scrape complete!
# Number of posts scraped:  129
#
# Page 16 of 22 scrape complete!
#
# Scraping page 17 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 126
#
# Individual posts scrape complete!
# Number of posts scraped:  126
#
# Page 17 of 22 scrape complete!
#
# Scraping page 18 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 126
#
# Individual posts scrape complete!
# Number of posts scraped:  126
#
# Page 18 of 22 scrape complete!
#
# Scraping page 19 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 122
#
# Individual posts scrape complete!
# Number of posts scraped:  122
#
# Page 19 of 22 scrape complete!
#
# Scraping page 20 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 125
#
# Individual posts scrape complete!
# Number of posts scraped:  125
#
# Page 20 of 22 scrape complete!
#
# Scraping page 21 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 129
#
# Individual posts scrape complete!
# Number of posts scraped:  129
#
# Page 21 of 22 scrape complete!
#
# Scraping page 22 of 22...
#
# Listing page scrape complete!
# Number of postings scraped: 122
#
# Individual posts scrape complete!
# Number of posts scraped:  122
#
# Page 22 of 22 scrape complete!
#       index    date                                              title  \
# 0         0  Jan 13                     Rent 3 bad.   1  . 5. Bathroom
# 1         1  Jan 13           3-bedroom, 1-bath farmhouse in Elk Grove
# 2         2  Jan 13  State of the Art Fitness Center, Stainless Ste...
# 3         3  Jan 13  Huge 2 Bedroom 2 Bath - just renovated with fu...
# 4         4  Jan 13          1x1 W/ Wrap Around Patio! Fully Upgraded!
# ...     ...     ...                                                ...
# 2737    117  Jan  6                      1 Bedroom Apartment available
# 2738    118  Jan  6                   Land for lease prop 215 friendly
# 2739    119  Jan  6        WiFi Available, Ceiling Fan, Fitness Center
# 2740    120  Jan  6                            1x1 $1475 Available NOW
# 2741    121  Jan  6   Ceiling Fan, Controlled Access, Air Conditioning
#
#                                                    link  price  brs    sqft  \
# 0     https://sacramento.craigslist.org/apa/d/sacram...   2100    3  1344.0
# 1     https://sacramento.craigslist.org/apa/d/elk-gr...   2200    3  1130.0
# 2     https://sacramento.craigslist.org/apa/d/fair-o...   2116    1   700.0
# 3     https://sacramento.craigslist.org/apa/d/west-s...   2308    2  1233.0
# 4     https://sacramento.craigslist.org/apa/d/rockli...   1950    1   774.0
# ...                                                 ...    ...  ...     ...
# 2737  https://sacramento.craigslist.org/apa/d/davis-...   1300    1   575.0
# 2738  https://sacramento.craigslist.org/apa/d/feathe...     30  NaN     NaN
# 2739  https://sacramento.craigslist.org/apa/d/west-s...   1986    1   786.0
# 2740  https://sacramento.craigslist.org/apa/d/sacram...   1325    1   600.0
# 2741  https://sacramento.craigslist.org/apa/d/west-s...   1986    1   786.0
#
#                                                    hood   bath  \
# 0                                          Sacramento    1.5Ba
# 1                                           Elk Grove      1Ba
# 2     Fair Oaks, Carmichael, Orangevale, Folsom, Cit...    1Ba
# 3                                                          2Ba
# 4                                             Rocklin      1Ba
# ...                                                 ...    ...
# 2737                            617 7th St Davis, CA.      1Ba
# 2738                                                       1Ba
# 2739                                                       1Ba
# 2740                                                       1Ba
# 2741                                                       1Ba
#
#                                               amenities
# 0     [flooring: other, townhouse, w/d in unit, no s...
# 1     [cats are OK - purrr, dogs are OK - wooof, flo...
# 2     [application fee details: $49 Application Fee ...
# 3     [cats are OK - purrr, dogs are OK - wooof, apa...
# 4     [cats are OK - purrr, dogs are OK - wooof, apa...
# ...                                                 ...
# 2737  [air conditioning, apartment, laundry on site,...
# 2738  [apartment, no laundry on site, off-street par...
# 2739  [cats are OK - purrr, dogs are OK - wooof, apa...
# 2740  [cats are OK - purrr, dogs are OK - wooof, flo...
# 2741  [cats are OK - purrr, dogs are OK - wooof, apa...
#
# [2742 rows x 10 columns]
